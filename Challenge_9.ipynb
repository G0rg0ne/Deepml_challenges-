# %%
import numpy as np

# %%
A = [[1,2],[2,4]]
B = [[2,1],[3,4]]

# %%
def matrixmul(a:list[list[int|float]],
              b:list[list[int|float]])-> list[list[int|float]]:
    if len(a[0]) != len(b):
        return -1
    height, width = len(a), len(b[0])
    result = [[0 for _ in range(width)] for _ in range(height)]
    for i in range(height):
        for j in range(width):
            result[i][j] = sum(a[i][k] * b[k][j] for k in range(len(b)))
    return result

# %%
print(matrixmul([[0,0],[2,4],[1,2]],[[0,0,1],[2,4,1],[1,2,3]]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(matrixmul([[0,0],[2,4],[1,2]],[[0,0,1],[2,4,1],[1,2,3]]))
#
# Cell In[10], line 7, in matrixmul(a, b)
#       5 for i in range(height):
#       6     for j in range(width):
# ----> 7         result[i][j] = sum(a[i][k] * b[k][j] for k in range(len(b)))
#       8 return result
#
# Cell In[10], line 7, in <genexpr>(.0)
#       5 for i in range(height):
#       6     for j in range(width):
# ----> 7         result[i][j] = sum(a[i][k] * b[k][j] for k in range(len(b)))
#       8 return result
#
# IndexError: list index out of range
